# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# Basic convolutional neural network
import keras_tuner as kt
from keras_tuner import BayesianOptimization
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Activation, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg19 import VGG19, preprocess_input
import os, numpy as np, time
from sklearn.metrics import accuracy_score
import pickle
import matplotlib.pyplot as plt

# %%
def hms(start, end):
    seconds = end-start
    m, s = divmod(seconds, 60)
    h, m = divmod(m, 60)
    return h,m,s

# %%
def create_model(hp):
    """
    Compiles a model integrated with pretrained layers
    
    """
    learning_rate = hp.Choice('learning_rate', values = [0.000001, 0.00001, 0.0001], default = 0.000001)
    dropout_rate = hp.Float('dropout', 0.2, 0.8, step=0.1)
    neurons = hp.Choice('neurons', values = [256, 512, 1024, 2048], default = 256)
    dense_layers = hp.Int('dense_layers', 0, 2, default = 0)
    pooling = hp.Choice("global_pooling", ["flatten", "avg"], default = 'flatten')
        
    # Pretrained convolutional layers are loaded using the Imagenet weights.
    # Include_top is set to False, in order to exclude the model's fully-connected layers.
    conv_base = VGG19(include_top=False,
                     weights='imagenet', 
                     input_shape=(224, 224, 3))
    
    # Layers in the convolutional base are switched from trainable to non-trainable
    for layer in conv_base.layers:
        layer.trainable = False

    # Create a new 'top' of the model (i.e. fully-connected layers).
    # This is 'bootstrapping' a new top_model onto the pretrained layers.
    top_model = conv_base.output
    
    # Choose top model pooling layer.
    if pooling == "avg":
        top_model = GlobalAveragePooling2D()(top_model)
        for dl in range(dense_layers):
            top_model = Dense(neurons, activation='relu')(top_model)
            top_model = Dropout(dropout_rate)(top_model)
    else:
        top_model = Flatten(name="flatten")(top_model)
        for dl in range(dense_layers):
            top_model = Dense(neurons, activation='relu')(top_model)
            top_model = Dropout(dropout_rate)(top_model)
    
    # Add final softmax layer for predictions
    output_layer = Dense(5, activation='softmax')(top_model)
    
    # Group the convolutional base and new fully-connected layers into a Model object.
    model = Model(inputs=conv_base.input, outputs=output_layer)

    # Compiles the model for training.
    model.compile(optimizer=Adam(learning_rate=learning_rate),
                                 loss='categorical_crossentropy', metrics=['accuracy'])
    #model.summary()
    return model

# %%
train_data_dir = 'cropped_resized_imgs/train'
test_data_dir = 'cropped_resized_imgs/test'
class_subset = sorted(os.listdir(train_data_dir))

img_size = 224
BATCH_SIZE = 128
totalstart = time.time()
modelName = 'VGG19'
filename = 'VGG19_HP_Tuning_Results.txt'

# create image generators with data augmentation
train_generator = ImageDataGenerator(
    width_shift_range=0.5,       # shift the width of the image 50%
    rotation_range=90,           # random rotation by 90 degrees
    horizontal_flip=True,        # 180 degree flip horizontally
    vertical_flip=True,          # 180 degree flip vertically
    validation_split=0.15,       # 15% of the data will be used for validation at end of each epoch
    preprocessing_function=preprocess_input # VGG16 preprocessing
)

traingen = train_generator.flow_from_directory(train_data_dir,
                                                target_size=(img_size, img_size),
                                                batch_size=BATCH_SIZE,
                                                class_mode='categorical',
                                                classes=class_subset,
                                                subset='training',
                                                shuffle=True,
                                                seed=55)

validgen = train_generator.flow_from_directory(train_data_dir,
                                                target_size=(img_size, img_size),
                                                batch_size=BATCH_SIZE,
                                                class_mode='categorical',
                                                classes=class_subset,
                                                subset='validation',
                                                shuffle=True,
                                                seed=55)

test_generator = ImageDataGenerator(preprocessing_function=preprocess_input)
testgen = test_generator.flow_from_directory(test_data_dir,
                                             target_size=(img_size, img_size),
                                             batch_size=1,
                                             class_mode=None,
                                             shuffle=False,
                                             seed=55)
# set values
n_epochs = 50
max_trial_epochs = 40
max_trials = 35
n_steps = traingen.samples / BATCH_SIZE
n_val_steps = validgen.samples / BATCH_SIZE

tuner = BayesianOptimization(create_model,
                objective='val_accuracy',
                max_trials=max_trials,
                directory='hp_models',
                project_name=modelName,
                overwrite=True,
                seed=55)

# Early Stopping
early_stop = EarlyStopping(monitor='val_loss',
                           patience=5,
                           restore_best_weights=True,
                           mode='min')

tuner.search(traingen,
            batch_size=BATCH_SIZE,
            epochs=max_trial_epochs,
            validation_data=validgen,
            steps_per_epoch=n_steps,
            validation_steps=n_val_steps,
            callbacks=[early_stop],
            workers=16,
            verbose=1)

# print and save tuner results
best_hp = tuner.get_best_hyperparameters(1)[0]
print(best_hp.values)

best_model = tuner.get_best_models(num_models=1)
print(best_model[0].summary())

print(tuner.results_summary(num_trials=max_trials))

with open(filename, 'w') as f:
    f.write('Best hyperparameters: {}\n\nBest Model Summary\n'.format(best_hp.values))
    best_model[0].summary(print_fn=lambda x: f.write(x + '\n'))

# ************************************************************************************************************
# train full model with hyperparameters

# ModelCheckpoint callback - save best weights
tl_checkpoint_1 = ModelCheckpoint(filepath='weights/{}.hp.weights.hdf5'.format(modelName),
                                  save_best_only=True,
                                  verbose=1)

# load and train model from hyperparameters
bestTunedModel = tuner.hypermodel.build(best_hp)
history = bestTunedModel.fit(traingen,
                    batch_size=BATCH_SIZE,
                    epochs=n_epochs,
                    validation_data=validgen,
                    steps_per_epoch=n_steps,
                    validation_steps=n_val_steps,
                    callbacks=[tl_checkpoint_1],
                    workers=16,
                    verbose=1)

# load model weights
bestTunedModel.load_weights('weights/{}.hp.weights.hdf5'.format(modelName)) # initialize the best trained weights
# get labels
labels = traingen.class_indices
labels = dict((v,k) for k,v in labels.items())

# Generate predictions
testgen.reset()
predstart = time.time()
preds = bestTunedModel.predict(testgen)
pred_classes = np.argmax(preds, axis=1)
true_classes = testgen.classes
acc = accuracy_score(true_classes, pred_classes)
predend = time.time()
avgPredictionTime = (predend - predstart)/1200

print("Best {} Model Accuracy: {:.2f}%".format(modelName, acc * 100))

# save history object to disk
with open('modelrun_history/{}.hp.history'.format(modelName), 'wb') as histfile:
    pickle.dump(history.history, histfile)

# save model accuracy to file
with open(filename, 'a') as f:
    f.write("{} Model Accuracy: {:.2f}%\n".format(modelName, acc * 100))
    f.write("Average prediction time per image: {} seconds\n".format(avgPredictionTime))

# total modeling time
totalEnd = time.time()
totalT=hms(totalstart, totalEnd)
print("Average prediction time per image: {} seconds\n".format(avgPredictionTime))
print('Total runtime is {:.0f} hours, {:.0f} minutes, {:.1f} seconds'.format(totalT[0],totalT[1],totalT[2]))
with open(filename, 'a') as f:
    f.write('Total runtime is {:.0f} hours, {:.0f} minutes, {:.1f} seconds'.format(totalT[0],totalT[1],totalT[2]))
# Out:
# Trial 35 Complete [00h 10m 07s]
# val_accuracy: 0.7388888597488403
#
# Best val_accuracy So Far: 0.7583333253860474
# Total elapsed time: 04h 36m 30s
# INFO:tensorflow:Oracle triggered exit
# {'learning_rate': 0.0001, 'dropout': 0.6000000000000001, 'neurons': 2048, 'dense_layers': 1, 'global_pooling': 'flatten'}
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 2048)              51382272
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 10245
# =================================================================
# Total params: 71,416,901
# Trainable params: 51,392,517
# Non-trainable params: 20,024,384
# _________________________________________________________________
# None
# Results summary
# Results in hp_models\VGG19
# Showing 35 best trials
# Objective(name='val_accuracy', direction='max')
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7583333253860474
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7472222447395325
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7444444298744202
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7444444298744202
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7402777671813965
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7388888597488403
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7388888597488403
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7361111044883728
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7361111044883728
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.730555534362793
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7277777791023254
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7277777791023254
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.7000000000000002
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7277777791023254
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7263888716697693
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7263888716697693
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7263888716697693
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7250000238418579
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.4000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7236111164093018
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7222222089767456
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7208333611488342
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.7000000000000002
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7208333611488342
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 2
# global_pooling: flatten
# Score: 0.7166666388511658
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7166666388511658
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.8000000000000003
# neurons: 2048
# dense_layers: 1
# global_pooling: flatten
# Score: 0.7152777910232544
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.2
# neurons: 2048
# dense_layers: 2
# global_pooling: flatten
# Score: 0.6930555701255798
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.2
# neurons: 2048
# dense_layers: 1
# global_pooling: avg
# Score: 0.6888889074325562
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.2
# neurons: 2048
# dense_layers: 2
# global_pooling: avg
# Score: 0.6888889074325562
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.2
# neurons: 2048
# dense_layers: 0
# global_pooling: flatten
# Score: 0.6666666865348816
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.6000000000000001
# neurons: 2048
# dense_layers: 2
# global_pooling: avg
# Score: 0.6652777791023254
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.2
# neurons: 256
# dense_layers: 2
# global_pooling: avg
# Score: 0.6625000238418579
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.8000000000000003
# neurons: 2048
# dense_layers: 0
# global_pooling: avg
# Score: 0.5847222208976746
# Trial summary
# Hyperparameters:
# learning_rate: 1e-05
# dropout: 0.5000000000000001
# neurons: 512
# dense_layers: 1
# global_pooling: avg
# Score: 0.5541666746139526
# Trial summary
# Hyperparameters:
# learning_rate: 1e-06
# dropout: 0.2
# neurons: 2048
# dense_layers: 2
# global_pooling: avg
# Score: 0.550000011920929
# Trial summary
# Hyperparameters:
# learning_rate: 0.0001
# dropout: 0.2
# neurons: 256
# dense_layers: 0
# global_pooling: avg
# Score: 0.5263888835906982
# Trial summary
# Hyperparameters:
# learning_rate: 1e-06
# dropout: 0.8000000000000003
# neurons: 256
# dense_layers: 1
# global_pooling: flatten
# Score: 0.37361112236976624
# None
# Epoch 1/50
# 31/31 [==============================] - 18s 473ms/step - loss: 5.6405 - accuracy: 0.6164 - val_loss: 5.2905 - val_accuracy: 0.6194
#
# Epoch 00001: val_loss improved from inf to 5.29055, saving model to weights\VGG19.hp.weights.hdf5
# Epoch 2/50
# 31/31 [==============================] - 16s 426ms/step - loss: 2.3803 - accuracy: 0.7980 - val_loss: 4.4791 - val_accuracy: 0.6333
#
# Epoch 00002: val_loss improved from 5.29055 to 4.47907, saving model to weights\VGG19.hp.weights.hdf5
# Epoch 3/50
# 31/31 [==============================] - 16s 428ms/step - loss: 1.5165 - accuracy: 0.8350 - val_loss: 4.3588 - val_accuracy: 0.6264
#
# Epoch 00003: val_loss improved from 4.47907 to 4.35882, saving model to weights\VGG19.hp.weights.hdf5
# Epoch 4/50
# 31/31 [==============================] - 15s 425ms/step - loss: 1.3215 - accuracy: 0.8436 - val_loss: 3.7095 - val_accuracy: 0.6333
#
# Epoch 00004: val_loss improved from 4.35882 to 3.70951, saving model to weights\VGG19.hp.weights.hdf5
# Epoch 5/50
# 31/31 [==============================] - 16s 426ms/step - loss: 1.1386 - accuracy: 0.8547 - val_loss: 3.3446 - val_accuracy: 0.6639
#
# Epoch 00005: val_loss improved from 3.70951 to 3.34458, saving model to weights\VGG19.hp.weights.hdf5
# Epoch 6/50
# 31/31 [==============================] - 15s 424ms/step - loss: 0.9199 - accuracy: 0.8652 - val_loss: 2.7163 - val_accuracy: 0.6708
#
# Epoch 00006: val_loss improved from 3.34458 to 2.71628, saving model to weights\VGG19.hp.weights.hdf5
# Epoch 7/50
# 31/31 [==============================] - 15s 425ms/step - loss: 0.7700 - accuracy: 0.8743 - val_loss: 2.2783 - val_accuracy: 0.6861
#
# Epoch 00007: val_loss improved from 2.71628 to 2.27826, saving model to weights\VGG19.hp.weights.hdf5
# Epoch 8/50
# 31/31 [==============================] - 16s 426ms/step - loss: 0.7374 - accuracy: 0.8789 - val_loss: 2.5126 - val_accuracy: 0.6667
#
# Epoch 00008: val_loss did not improve from 2.27826
# Epoch 9/50
# 31/31 [==============================] - 16s 429ms/step - loss: 0.6158 - accuracy: 0.8929 - val_loss: 1.9522 - val_accuracy: 0.7028
#
# Epoch 00009: val_loss improved from 2.27826 to 1.95222, saving model to weights\VGG19.hp.weights.hdf5
# Epoch 10/50
# 31/31 [==============================] - 16s 427ms/step - loss: 0.5304 - accuracy: 0.8931 - val_loss: 2.1378 - val_accuracy: 0.7125
#
# Epoch 00010: val_loss did not improve from 1.95222
# Epoch 11/50
# 31/31 [==============================] - 16s 425ms/step - loss: 0.4968 - accuracy: 0.8963 - val_loss: 2.3274 - val_accuracy: 0.6931
#
# Epoch 00011: val_loss did not improve from 1.95222
# Epoch 12/50
# 31/31 [==============================] - 16s 430ms/step - loss: 0.4988 - accuracy: 0.9015 - val_loss: 1.8685 - val_accuracy: 0.6861
#
# Epoch 00012: val_loss improved from 1.95222 to 1.86846, saving model to weights\VGG19.hp.weights.hdf5
# Epoch 13/50
# 31/31 [==============================] - 16s 426ms/step - loss: 0.4754 - accuracy: 0.8978 - val_loss: 1.9399 - val_accuracy: 0.6958
#
# Epoch 00013: val_loss did not improve from 1.86846
# Epoch 14/50
# 31/31 [==============================] - 16s 426ms/step - loss: 0.4646 - accuracy: 0.8953 - val_loss: 1.8675 - val_accuracy: 0.7028
#
# Epoch 00014: val_loss improved from 1.86846 to 1.86746, saving model to weights\VGG19.hp.weights.hdf5
# Epoch 15/50
# 31/31 [==============================] - 15s 426ms/step - loss: 0.4221 - accuracy: 0.9025 - val_loss: 1.8578 - val_accuracy: 0.6764
#
# Epoch 00015: val_loss improved from 1.86746 to 1.85780, saving model to weights\VGG19.hp.weights.hdf5
# Epoch 16/50
# 31/31 [==============================] - 16s 429ms/step - loss: 0.4199 - accuracy: 0.9037 - val_loss: 1.8565 - val_accuracy: 0.6833
#
# Epoch 00016: val_loss improved from 1.85780 to 1.85650, saving model to weights\VGG19.hp.weights.hdf5
# Epoch 17/50
# 31/31 [==============================] - 16s 428ms/step - loss: 0.3691 - accuracy: 0.9108 - val_loss: 1.6074 - val_accuracy: 0.6875
#
# Epoch 00017: val_loss improved from 1.85650 to 1.60745, saving model to weights\VGG19.hp.weights.hdf5
# Epoch 18/50
# 31/31 [==============================] - 16s 427ms/step - loss: 0.3017 - accuracy: 0.9167 - val_loss: 1.5103 - val_accuracy: 0.7097
#
# Epoch 00018: val_loss improved from 1.60745 to 1.51026, saving model to weights\VGG19.hp.weights.hdf5
# Epoch 19/50
# 31/31 [==============================] - 16s 428ms/step - loss: 0.3627 - accuracy: 0.9064 - val_loss: 1.3464 - val_accuracy: 0.7139
#
# Epoch 00019: val_loss improved from 1.51026 to 1.34641, saving model to weights\VGG19.hp.weights.hdf5
# Epoch 20/50
# 31/31 [==============================] - 15s 426ms/step - loss: 0.3496 - accuracy: 0.9083 - val_loss: 1.5522 - val_accuracy: 0.6764
#
# Epoch 00020: val_loss did not improve from 1.34641
# Epoch 21/50
# 31/31 [==============================] - 16s 429ms/step - loss: 0.3113 - accuracy: 0.9103 - val_loss: 1.6980 - val_accuracy: 0.7014
#
# Epoch 00021: val_loss did not improve from 1.34641
# Epoch 22/50
# 31/31 [==============================] - 16s 425ms/step - loss: 0.3110 - accuracy: 0.9176 - val_loss: 1.5356 - val_accuracy: 0.7181
#
# Epoch 00022: val_loss did not improve from 1.34641
# Epoch 23/50
# 31/31 [==============================] - 16s 431ms/step - loss: 0.3085 - accuracy: 0.9181 - val_loss: 1.4589 - val_accuracy: 0.6958
#
# Epoch 00023: val_loss did not improve from 1.34641
# Epoch 24/50
# 31/31 [==============================] - 19s 505ms/step - loss: 0.2959 - accuracy: 0.9174 - val_loss: 1.4953 - val_accuracy: 0.6819
#
# Epoch 00024: val_loss did not improve from 1.34641
# Epoch 25/50
# 31/31 [==============================] - 21s 515ms/step - loss: 0.2807 - accuracy: 0.9216 - val_loss: 1.3831 - val_accuracy: 0.7181
#
# Epoch 00025: val_loss did not improve from 1.34641
# Epoch 26/50
# 31/31 [==============================] - 18s 478ms/step - loss: 0.2679 - accuracy: 0.9225 - val_loss: 1.4131 - val_accuracy: 0.7181
#
# Epoch 00026: val_loss did not improve from 1.34641
# Epoch 27/50
# 31/31 [==============================] - 17s 444ms/step - loss: 0.2663 - accuracy: 0.9243 - val_loss: 1.2328 - val_accuracy: 0.7222
#
# Epoch 00027: val_loss improved from 1.34641 to 1.23277, saving model to weights\VGG19.hp.weights.hdf5
# Epoch 28/50
# 31/31 [==============================] - 16s 428ms/step - loss: 0.2784 - accuracy: 0.9221 - val_loss: 1.3066 - val_accuracy: 0.7389
#
# Epoch 00028: val_loss did not improve from 1.23277
# Epoch 29/50
# 31/31 [==============================] - 17s 439ms/step - loss: 0.2578 - accuracy: 0.9250 - val_loss: 1.4891 - val_accuracy: 0.6694
#
# Epoch 00029: val_loss did not improve from 1.23277
# Epoch 30/50
# 31/31 [==============================] - 18s 482ms/step - loss: 0.2568 - accuracy: 0.9255 - val_loss: 1.3895 - val_accuracy: 0.6986
#
# Epoch 00030: val_loss did not improve from 1.23277
# Epoch 31/50
# 31/31 [==============================] - 17s 445ms/step - loss: 0.2358 - accuracy: 0.9284 - val_loss: 1.1055 - val_accuracy: 0.7194
#
# Epoch 00031: val_loss improved from 1.23277 to 1.10551, saving model to weights\VGG19.hp.weights.hdf5
# Epoch 32/50
# 31/31 [==============================] - 18s 476ms/step - loss: 0.2524 - accuracy: 0.9252 - val_loss: 1.4040 - val_accuracy: 0.7139
#
# Epoch 00032: val_loss did not improve from 1.10551
# Epoch 33/50
# 31/31 [==============================] - 17s 434ms/step - loss: 0.2298 - accuracy: 0.9321 - val_loss: 1.2521 - val_accuracy: 0.7278
#
# Epoch 00033: val_loss did not improve from 1.10551
# Epoch 34/50
# 31/31 [==============================] - 17s 442ms/step - loss: 0.2284 - accuracy: 0.9265 - val_loss: 1.2548 - val_accuracy: 0.6972
#
# Epoch 00034: val_loss did not improve from 1.10551
# Epoch 35/50
# 31/31 [==============================] - 17s 441ms/step - loss: 0.2293 - accuracy: 0.9282 - val_loss: 1.3240 - val_accuracy: 0.7139
#
# Epoch 00035: val_loss did not improve from 1.10551
# Epoch 36/50
# 31/31 [==============================] - 17s 441ms/step - loss: 0.2449 - accuracy: 0.9287 - val_loss: 1.2308 - val_accuracy: 0.7181
#
# Epoch 00036: val_loss did not improve from 1.10551
# Epoch 37/50
# 31/31 [==============================] - 16s 433ms/step - loss: 0.2113 - accuracy: 0.9365 - val_loss: 1.3777 - val_accuracy: 0.7208
#
# Epoch 00037: val_loss did not improve from 1.10551
# Epoch 38/50
# 31/31 [==============================] - 16s 427ms/step - loss: 0.2097 - accuracy: 0.9353 - val_loss: 1.3937 - val_accuracy: 0.7014
#
# Epoch 00038: val_loss did not improve from 1.10551
# Epoch 39/50
# 31/31 [==============================] - 16s 425ms/step - loss: 0.2259 - accuracy: 0.9311 - val_loss: 1.2756 - val_accuracy: 0.7306
#
# Epoch 00039: val_loss did not improve from 1.10551
# Epoch 40/50
# 31/31 [==============================] - 16s 426ms/step - loss: 0.2371 - accuracy: 0.9292 - val_loss: 1.2501 - val_accuracy: 0.7000
#
# Epoch 00040: val_loss did not improve from 1.10551
# Epoch 41/50
# 31/31 [==============================] - 16s 427ms/step - loss: 0.1963 - accuracy: 0.9370 - val_loss: 1.2470 - val_accuracy: 0.7167
#
# Epoch 00041: val_loss did not improve from 1.10551
# Epoch 42/50
# 31/31 [==============================] - 16s 425ms/step - loss: 0.2047 - accuracy: 0.9375 - val_loss: 1.2440 - val_accuracy: 0.7097
#
# Epoch 00042: val_loss did not improve from 1.10551
# Epoch 43/50
# 31/31 [==============================] - 16s 426ms/step - loss: 0.1906 - accuracy: 0.9392 - val_loss: 1.1811 - val_accuracy: 0.7319
#
# Epoch 00043: val_loss did not improve from 1.10551
# Epoch 44/50
# 31/31 [==============================] - 16s 422ms/step - loss: 0.1988 - accuracy: 0.9355 - val_loss: 1.2292 - val_accuracy: 0.7306
#
# Epoch 00044: val_loss did not improve from 1.10551
# Epoch 45/50
# 31/31 [==============================] - 16s 428ms/step - loss: 0.1999 - accuracy: 0.9390 - val_loss: 1.3651 - val_accuracy: 0.6986
#
# Epoch 00045: val_loss did not improve from 1.10551
# Epoch 46/50
# 31/31 [==============================] - 16s 425ms/step - loss: 0.1994 - accuracy: 0.9382 - val_loss: 1.2821 - val_accuracy: 0.7333
#
# Epoch 00046: val_loss did not improve from 1.10551
# Epoch 47/50
# 31/31 [==============================] - 16s 426ms/step - loss: 0.1735 - accuracy: 0.9404 - val_loss: 1.3487 - val_accuracy: 0.7028
#
# Epoch 00047: val_loss did not improve from 1.10551
# Epoch 48/50
# 31/31 [==============================] - 16s 424ms/step - loss: 0.1954 - accuracy: 0.9400 - val_loss: 1.1241 - val_accuracy: 0.7222
#
# Epoch 00048: val_loss did not improve from 1.10551
# Epoch 49/50
# 31/31 [==============================] - 16s 423ms/step - loss: 0.1645 - accuracy: 0.9488 - val_loss: 1.1289 - val_accuracy: 0.7319
#
# Epoch 00049: val_loss did not improve from 1.10551
# Epoch 50/50
# 31/31 [==============================] - 16s 424ms/step - loss: 0.1802 - accuracy: 0.9387 - val_loss: 1.2836 - val_accuracy: 0.7278
#
# Epoch 00050: val_loss did not improve from 1.10551
# Best VGG19 Model Accuracy: 93.92%
# Average prediction time per image: 0.006813093821207683 seconds
#
# Total runtime is 4 hours, 51 minutes, 11.1 seconds

# %%
# plot training/validation accuracy and loss
plt.figure(figsize=(12, 6)) # figsize(width, height) in inches, dpi=100
# plot accuracy
plt.subplot(1, 2, 1) # (rows, cols, index)
plt.plot(history.history["accuracy"])
plt.plot(history.history['val_accuracy'])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy", "Validation Accuracy"])

plt.subplot(1, 2, 2) # (rows, cols, index)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Loss", "Validation Loss"])
